# %% [markdown]
# <a href="https://colab.research.google.com/github/kty9798/machine_learning_study/blob/main/%ED%85%8D%EC%8A%A4%ED%8A%B8_%EB%B6%84%EB%A5%98_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ### 자연어 처리 (naturual language processing)
#
# * 텍스트 분류
# * 감정 분석
# * 요약 , 기계번역 , 질문 응답

# %% [markdown]
# ### 주목 받을만한 청원 분류하기

# %% [markdown]
# 1. 국민청원 페이지 크롤링
# 2. 전처리
# 3. 토크나이징 및 변수 생성
# 4. 단어 임베딩
# 5. 실험 설계
# 6. TextCnn

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import time
import requests

# %%
result = pd.DataFrame()                                    

for i in range(584274, 584321):
    URL = "http://www1.president.go.kr/petitions/"+str(i)
 
    response = requests.get(URL)    
    html = response.text                                   
    soup = BeautifulSoup(html, 'html.parser')           

    title = soup.find('h3', class_='petitionsView_title')
    count = soup.find('span', class_='counter')           

    for content in soup.select('div.petitionsView_write > div.View_write'):
        content                                         

    a=[]
    for tag in soup.select('ul.petitionsView_info_list > li'): 
        a.append(tag.contents[1])
    
    print(len(a) >0)
    if len(a) != 0:
        df1=pd.DataFrame({ 'start' : [a[1]],                
                           'end' : [a[2]],                     
                           'category' :  [a[0]],               
                           'count' : [count.text],             
                           'title': [title.text],              
                           'content': [content.text.strip()[0:13000]]                              
                         })

        result=pd.concat([result, df1])                        
        result.index = np.arange(len(result))   
        print(result.shape)
# Out:
# True
# (1, 6)
# True
# (2, 6)
# True
# (3, 6)
# True
# (4, 6)
# True
# (5, 6)
# True
# (6, 6)
# True
# (7, 6)
# True
# (8, 6)
# True
# (9, 6)
# True
# (10, 6)
# True
# (11, 6)
# True
# (12, 6)
# True
# (13, 6)
# True
# (14, 6)
# True
# (15, 6)
# True
# (16, 6)
# True
# (17, 6)
# True
# (18, 6)
# True
# (19, 6)
# True
# (20, 6)
# True
# (21, 6)
# True
# (22, 6)
# True
# (23, 6)
# True
# (24, 6)
# True
# (25, 6)
# True
# (26, 6)
# True
# (27, 6)
# True
# (28, 6)
# True
# (29, 6)
# True
# (30, 6)
# True
# (31, 6)
# True
# (32, 6)
# True
# (33, 6)
# True
# (34, 6)
# True
# (35, 6)
# True
# (36, 6)
# True
# (37, 6)
# True
# (38, 6)
# True
# (39, 6)
# True
# (40, 6)
# True
# (41, 6)
# True
# (42, 6)
# True
# (43, 6)
# True
# (44, 6)
# True
# (45, 6)
# True
# (46, 6)
# True
# (47, 6)

# %%
result.head()
# Out:
#         start  ...                                            content
# 0  2020-01-02  ...  본인은 2019년 8월 경 서울지방병무청 제1검사장 탈의실에서 믿을 수 없는 것을 ...
# 1  2020-01-02  ...  우리 나라 코스피 시총이 미국 애플보다 작다는 설이 돌 정도로 한국의 주식시장은 저...
# 2  2020-01-02  ...  억울한 일로 국민청원을 신청합니다.\n\r\n 저는 **구치소 **교도관입니다.\n...
# 3  2020-01-02  ...  미세먼지의 심각성은 이제 적극적인 대안을 요구 하고 있습니다.\r\n우리 일상에서 ...
# 4  2020-01-02  ...  저는 우선 아이셋의 부모입니다.\r\n식구가 많은편이고 아이들이 성장함에 따라 집이...
#
# [5 rows x 6 columns]

# %%
result.shape
df = result
print(result.shape)
# Out:
# (47, 6)

# %%
df.loc[1]["content"]
# Out:
# '우리 나라 코스피 시총이 미국 애플보다 작다는 설이 돌 정도로 한국의 주식시장은 저평가된 시장이라고 합니다. 하지만 투자매력이 없다고도 합니다.이렇게 말하는 이유가 어디 있습니까? 바로 투자를 해도 수익을 기대하기 어렵다는 인식이 이미 널리 퍼져 있다는 것입니다.\n\r\n지금은 투자매력이 없어서 그렇지,..우리 나라 시중 부동 자금이 어마어마 한 것으로 알려진 것과, 외국 투자 자본 또한 실로 어마무지하게 많다는 것도 알고있습니다. 그러나 이 투자금이 주식시장으로 원활하게 순환이 안되고 있다는데 있습니다.\n\r\n정부는 유휴자금이 주식 시장으로 들어오게 분위기를 띄어줘야 하는데,... 그렇지 못한 현실이 안타깝다고 생각합니다.\r\n국가가 지원해 돈 들이기가 어려우면,정부에서 정서적인 말이라도 활성화를 위한 관심표명과 정책적으로 지원만 해도 시장분위기는 많이 좋아질 것이라 확신합니다. \n\r\n그래서 저는 정부에 다음과 같이 청원합니다.\r\n주식시장에 더 큰 충격 오기 전에 정부가 예방 조치를 할 수 있는데까지 노력해 주시기를 당부 드리면서,...\n\r\n첫째,주식시장 활성화와 부양에 대한 정부의 의지를 표명해 주십시오 \n\r\n둘째,  코스닥 종목은 공매도 제외시켜 주세요.\n\r\n공매도 제도를 아예 없애버리면 좋겠지만 제도를 살린다면 적용 시장에서 코스닥 종목은 제외 해 주어야 체력이 약한 코스닥 시장을 안정시킬 수 있다고 봅니다 \n\r\n셋째, 거래시장의 주식거래세를 더 낮춰 주세요 \n\r\n특히 개미(소액)투자에 동일한 요율로 부과하는 것은 너무나 불공정 하다고 봅니다.\n\r\n넷째, 중,장기 보유자에 대한 우대 차원에서 보유기간을 설정하여 주세요.\n\r\n이는 장기 보유자에 대한 혜택을 주어 초단타매매 등 시장 질서를 교란하는 투자자와 분리하는 제도를 도입해 시장 안정화에 기여해 주시길 간곡히 부탁드리면서 청원합니다.'

# %%
df
# Out:
#          start  ...                                            content
# 0   2020-01-02  ...  본인은 2019년 8월 경 서울지방병무청 제1검사장 탈의실에서 믿을 수 없는 것을 ...
# 1   2020-01-02  ...  우리 나라 코스피 시총이 미국 애플보다 작다는 설이 돌 정도로 한국의 주식시장은 저...
# 2   2020-01-02  ...  억울한 일로 국민청원을 신청합니다.\n\r\n 저는 **구치소 **교도관입니다.\n...
# 3   2020-01-02  ...  미세먼지의 심각성은 이제 적극적인 대안을 요구 하고 있습니다.\r\n우리 일상에서 ...
# 4   2020-01-02  ...  저는 우선 아이셋의 부모입니다.\r\n식구가 많은편이고 아이들이 성장함에 따라 집이...
# 5   2020-01-02  ...  [제목없음]\r\n파주***의 협력업체직원에 대한 갑질해고의 근절을 청원합니다.\n...
# 6   2020-01-02  ...  중고물품을 거래하는 인터넷 사이트에서 사기꾼들이 활개를 치며 사기행각을 벌이고 있습...
# 7   2020-01-02  ...  국민의 의견과 미래를 제대로 보지 못한  졸속 선심 외교 정책입니다. 되돌릴 방안을...
# 8   2020-01-02  ...  2019.2.5일저녁7시40분경 남자친구와 남자친구가족들과 집앞치킨집에갔습니다.약 ...
# 9   2020-01-02  ...  국내 최대의 헤지 펀드운용사 '**자산운용'  경영자들의 도덕적 해이를 고발합니다....
# 10  2020-01-02  ...  웹하드, 단톡방에 이은  'n번방'을 아십니까?\n\r\n지난 2019년, 불법 영...
# 11  2020-01-02  ...  통과한 공수처법 중,\r\n1."공수처장은 추천위원회 7명 중 6명의 찬성으로 결정...
# ...

# %% [markdown]
# 공백이나 탭 그리고 엔터 적용

# %%
import re #정규 표현식

def remove_white_space(text):
  text = re.sub(r'[\t\r\n\f\v]' , ' ' , str(text))
  return text

def remove_special_char(text):
  text = re.sub('[^ ㄱ-ㅣ가-힣 0-9]+' , ' ', str(text))
  return text



df.title= df.title.apply(remove_white_space)
df.title = df.title.apply(remove_special_char)
df.content= df.content.apply(remove_white_space)
df.content= df.content.apply(remove_special_char)

# %%
df.title
# Out:
# 0     서울지방병무청 탈의실에 설치된  에 대한 진상규명을 요구한다  또한 인권위의 미온적...
# 1                               주식시장 활성화 및 소액 개미 투자자 보호
# 2                                              교정기관의 민낮
# 3                                            미세먼지 저감 대책
# 4                          악질세입자 방지를 위한 세입자보호법을 재정해주세요
# 5                        파주 의 협력업체직원에대한 갑질해고의 근절응처원합니다
# 6     인터넷 사기 근절을 위한 지급정지제도 신설 및 사이버수사대 인력보강 및 기구 증설을...
# 7           필리핀 인도네시아 베트남 무비자 제주도 관광 입국과 내륙5일 체류 반대합니다
# 8                                   군산보복폭행  피해자는 억울합니다
# 9                     자산 운용 비리에 대하여 즉각적인 수사 진행을 해야 합니다
# 10       성 착취 사건인  번방 사건 의 근본적인 해결을 위한 국제 공조 수사를 청원합니다
# 11                          공수처장은 국민이 추천하고 국민이 뽑아야 합니다
# 12                전북대 수의대생 이윤희양 실종사건 해결을 위한 단서가 발견됐습니다
# 13                       제주도내 소방안전시설 가스안전시설 점검강화 요청합니다
# 14                              사설유기견보호소  정부가 책임져야 합니다
# 15                       검찰 행태를 개탄하며 국민 여러분들의 도움을 요청합니다
# 16                       일본이 대마도를 우리나라에 반환할 수 있도록 해주세요
# ...

# %%
df.loc[1]['content']
# Out:
# '우리 나라 코스피 시총이 미국 애플보다 작다는 설이 돌 정도로 한국의 주식시장은 저평가된 시장이라고 합니다  하지만 투자매력이 없다고도 합니다 이렇게 말하는 이유가 어디 있습니까  바로 투자를 해도 수익을 기대하기 어렵다는 인식이 이미 널리 퍼져 있다는 것입니다    지금은 투자매력이 없어서 그렇지 우리 나라 시중 부동 자금이 어마어마 한 것으로 알려진 것과  외국 투자 자본 또한 실로 어마무지하게 많다는 것도 알고있습니다  그러나 이 투자금이 주식시장으로 원활하게 순환이 안되고 있다는데 있습니다    정부는 유휴자금이 주식 시장으로 들어오게 분위기를 띄어줘야 하는데  그렇지 못한 현실이 안타깝다고 생각합니다   국가가 지원해 돈 들이기가 어려우면 정부에서 정서적인 말이라도 활성화를 위한 관심표명과 정책적으로 지원만 해도 시장분위기는 많이 좋아질 것이라 확신합니다     그래서 저는 정부에 다음과 같이 청원합니다   주식시장에 더 큰 충격 오기 전에 정부가 예방 조치를 할 수 있는데까지 노력해 주시기를 당부 드리면서    첫째 주식시장 활성화와 부양에 대한 정부의 의지를 표명해 주십시오    둘째   코스닥 종목은 공매도 제외시켜 주세요    공매도 제도를 아예 없애버리면 좋겠지만 제도를 살린다면 적용 시장에서 코스닥 종목은 제외 해 주어야 체력이 약한 코스닥 시장을 안정시킬 수 있다고 봅니다    셋째  거래시장의 주식거래세를 더 낮춰 주세요    특히 개미 소액 투자에 동일한 요율로 부과하는 것은 너무나 불공정 하다고 봅니다    넷째  중 장기 보유자에 대한 우대 차원에서 보유기간을 설정하여 주세요    이는 장기 보유자에 대한 혜택을 주어 초단타매매 등 시장 질서를 교란하는 투자자와 분리하는 제도를 도입해 시장 안정화에 기여해 주시길 간곡히 부탁드리면서 청원합니다 '

# %% [markdown]
# ### 토그나이징(문장을 의미있는 부분으로 나누는 과정)

# %% [markdown]
# * 청원 제목-> 형태소 단위
# * 청원 내용 -> 명사 단위

# %%
# !pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 448 kB 45.7 MB/s
# ...

# %%
from konlpy.tag import Okt #형태소 분석기 패키지로 okt , Kkma , komoran . mecab

okt = Okt()

df["title_token"] = df.title.apply(okt.morphs)
df["content_token"] = df.content.apply(okt.nouns)

# %%
df["token_final"] = df["title_token"] + df["content_token"]

# %%
df["count"] = df["count"].replace({',' : ''} , regex = True).apply(lambda x : int(x))

# %%
df.head()
# Out:
#         start  ...                                        token_final
# 0  2020-01-02  ...  [서울, 지방, 병무청, 탈의실, 에, 설치, 된, 에, 대한, 진상, 규명, 을,...
# 1  2020-01-02  ...  [주식시장, 활성화, 및, 소액, 개미, 투자자, 보호, 우리, 나라, 코스피, 총...
# 2  2020-01-02  ...  [교정, 기관, 의, 민낮, 일로, 국민, 청원, 신청, 저, 구치소, 교도관, 이...
# 3  2020-01-02  ...  [미세먼지, 저, 감, 대책, 미세먼지, 심각, 성은, 이제, 적극, 대안, 요구,...
# 4  2020-01-02  ...  [악질, 세, 입자, 방지, 를, 위, 한, 세, 입자, 보호, 법, 을, 재정, ...
#
# [5 rows x 9 columns]

# %%
print(df.dtypes)
# Out:
# start            object
# end              object
# category         object
# count             int64
# title            object
# content          object
# title_token      object
# content_token    object
# token_final      object
# dtype: object

# %%
df["label"] = df["count"].apply(lambda x : "Yes" if x >=1000 else "No")

# %%
df_drop= df[['token_final' , 'label']]

# %%
df.label.value_counts()
# Out:
# No     30
# Yes    17
# Name: label, dtype: int64

# %%
df_drop
# Out:
#                                           token_final label
# 0   [서울, 지방, 병무청, 탈의실, 에, 설치, 된, 에, 대한, 진상, 규명, 을,...    No
# 1   [주식시장, 활성화, 및, 소액, 개미, 투자자, 보호, 우리, 나라, 코스피, 총...    No
# 2   [교정, 기관, 의, 민낮, 일로, 국민, 청원, 신청, 저, 구치소, 교도관, 이...    No
# 3   [미세먼지, 저, 감, 대책, 미세먼지, 심각, 성은, 이제, 적극, 대안, 요구,...    No
# 4   [악질, 세, 입자, 방지, 를, 위, 한, 세, 입자, 보호, 법, 을, 재정, ...   Yes
# 5   [파주, 의, 협력, 업체, 직원, 에, 대한, 갑질, 해고, 의, 근절, 응처, ...   Yes
# 6   [인터넷, 사기, 근절, 을, 위, 한, 지, 급정지, 제도, 신설, 및, 사이버수...   Yes
# 7   [필리핀, 인도네시아, 베트남, 무비, 자, 제주도, 관광, 입국, 과, 내륙, 5...    No
# 8   [군산, 보복, 폭행, 피해자, 는, 억울합니다, 남자친구, 남자친구, 가족, 집앞...    No
# 9   [자산, 운용, 비리, 에, 대하, 여, 즉각, 적, 인, 수사, 진행, 을, 해야...    No
# 10  [성, 착취, 사건, 인, 번방, 사건, 의, 근본, 적, 인, 해결, 을, 위, ...   Yes
# 11  [공, 수, 처, 장, 은, 국민, 이, 추천, 하고, 국민, 이, 뽑아야, 합니다...   Yes
# 12  [전북대, 수의, 대, 생, 이윤희, 양, 실종, 사건, 해결, 을, 위, 한, 단...    No
# 13  [제주도, 내, 소방, 안전, 시설, 가스, 안전, 시설, 점검, 강화, 요청, 합...    No
# 14  [사설, 유기견, 보호, 소, 정부, 가, 책임져야, 합니다, 사설, 유기견, 보호...   Yes
# ...

# %% [markdown]
# ### 문자를 숫자로 바꿔서 컴퓨터가 이해할수 있도록 변환하는 word Embedding 과정 필요

# %% [markdown]
# 산업데이터때 배웠듯이 단순히 숫자로 치완하거나 기초적인 one-hot-encoding 방식이 있음(Dummy variable)
#
# - 원핫은 단어의 유사성을 판단할 수 없고
# - 변수의 희소성으로 자원을 비효율적으로 사용
# - 컴퓨팅 비용이 급수적으로 증가

# %% [markdown]
# #### Word2Vec

# %% [markdown]
# 토큰의 의미가 주변 정보로 인해 표현된다
#
# - 방식은 크게 CBOW 와 Skip-Gram 방식(가중치 행렬을 학습할 때)

# %%
from gensim.models import Word2Vec

# %%
embedding_model = Word2Vec(df_drop["token_final"] ,
                           sg = 1, #1 -> skip-Gram
                           size= 100,
                           window =2 ,
                           min_count = 1,
                           workers = 4                           
                           )
print(embedding_model)

model_result = embedding_model.wv.most_similar("코스피")
print(model_result)
# Out:
# Word2Vec(vocab=4238, size=100, alpha=0.025)
# [('돼지', 0.36753401160240173), ('해운대', 0.3588653802871704), ('면전', 0.338222861289978), ('즉석', 0.32720014452934265), ('수레', 0.312863826751709), ('원시', 0.31254252791404724), ('령', 0.30440425872802734), ('메이지', 0.302720844745636), ('오', 0.29527878761291504), ('비정규직', 0.2935008704662323)]

# %%
#from gensim.models import KeyedVecters

#embedding_model.wv.save_word2vec_format('data/petitions_tokens_w2v')

# %% [markdown]
# ### 실험 설계

# %%
from numpy.random import RandomState

# %%
from numpy.random import RandomState

rng = RandomState()

tr = df_drop.sample(frac=0.8, random_state=rng)
val = df_drop.loc[~df_drop.index.isin(tr.index)]

tr.to_csv('train.csv', index=False, encoding='utf-8-sig')
val.to_csv('validation.csv', index=False, encoding='utf-8-sig')

# %%
# !pip install -U torchtext==0.6.0
# Out:
# ...
#      |████████████████████████████████| 64 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 12.2 MB/s
# ...
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.11.0
#     Uninstalling torchtext-0.11.0:
#       Successfully uninstalled torchtext-0.11.0
# ...

# %%
from torchtext.data import Field

def tokenizer(text):
  text = re.sub('[\[\]\']' , '' , str(text))
  text= text.split(', ')
  return text

TEXT = Field(tokenize  = tokenizer)
LABEL = Field(sequential = False)

# %%
#임베딩 모델 저장 및 로드

# %%
from gensim.models import KeyedVectors

embedding_model.wv.save_word2vec_format('petitions_tokens_w2v') # 모델 저장
loaded_model = KeyedVectors.load_word2vec_format('petitions_tokens_w2v') # 모델 로드

model_result = loaded_model.most_similar("해운대")
print(model_result)
# Out:
# [('강행', 0.3984612226486206), ('협박', 0.39785778522491455), ('공존', 0.3904256224632263), ('황룡산', 0.38837742805480957), ('응급', 0.36492228507995605), ('지방검찰청', 0.3626914918422699), ('코스피', 0.358865350484848), ('쓰레기', 0.3432784378528595), ('조선', 0.33380648493766785), ('속셈', 0.3296910226345062)]

# %%
import torchtext

# %%
from torchtext.data import TabularDataset

train, validation = TabularDataset.splits(
    path = '',
    train = 'train.csv',
    validation = 'validation.csv',
    format = 'csv',
    fields = [('text', TEXT), ('label', LABEL)],
    skip_header = True
)

print("Train:", train[0].text,  train[0].label)
print("Validation:", validation[0].text, validation[0].label);
# Out:
# Train: ['성', '착취', '사건', '인', '번방', '사건', '의', '근본', '적', '인', '해결', '을', '위', '한', '국제', '공조', '수사', '를', '청원', '합니다', '웹하드', '톡방', '은', '번방', '지난', '불법', '영상', '물', '관련', '웹하드', '업체', '필터', '링', '업체', '디지털', '장의', '업체', '간', '유착', '관계', '형성', '이득', '취하', '웹하드', '카르텔', '유명', '연예인', '단체', '방', '불법', '촬영', '물', '유포', '톡방', '착취', '물', '공유', '사건', '이', '이', '두', '사건', '공론', '사회', '충격', '디지털', '성범죄', '대한', '각심', '웹하드', '카르텔', '붕괴', '단체', '방', '통한', '착취', '물', '공유', '행각', '대한', '처벌', '가해자', '또', '다른', '유통', '경로', '바로', '텔레', '그램', '텔레그램', '독일', '사가', '개발', '및', '운영', '중인', '인터넷', '모바일', '메신저', '이', '텔레그램', '통한', '성', '착취', '시초', '지난', '개설', '번방', '번방', '피해자', '신상', '정보', '성', '착취', '물', '공유', '위', '목적', '개설', '텔레', '그램', '비밀방', '의미', '가해자', '텔레그램', '비밀방', '개설', '피해자', '신상', '정보', '성', '착취', '물', '공유', '블로그', '실시간', '홍보', '홍보', '글', '보고', '연락', '자', '문화', '상품권', '기프티콘', '현금', '등', '번방', '링크', '공유', '성폭력', '범죄', '처벌', '등', '관', '특례법', '제', '항', '근거', '범죄', '행위', '가해자', '피해자', '신상', '정보', '성
# ...

# %%
# !pip install BucketIterator
# Out:
# ERROR: Could not find a version that satisfies the requirement BucketIterator (from versions: none)
# ERROR: No matching distribution found for BucketIterator

# %%
import torch
from torchtext.vocab import Vectors
from torchtext.data import BucketIterator

vectors = Vectors(name="petitions_tokens_w2v")

TEXT.build_vocab(train, vectors = vectors, min_freq = 1, max_size = None)
LABEL.build_vocab(train)

vocab = TEXT.vocab

device = "cuda"

train_iter, validation_iter = BucketIterator.splits(
    datasets = (train, validation),
    batch_size = 8,
    device = device,
    sort = False
)

print('임베딩 벡터의 개수와 차원 : {} '.format(TEXT.vocab.vectors.shape))
# Out:
# ...
# 100%|██████████| 4238/4238 [00:00<00:00, 15135.26it/s]
# 임베딩 벡터의 개수와 차원 : torch.Size([3882, 100])

# %%
import torch.nn as nn
import torch.optim as  optim
import torch.nn.functional as F

class TextCNN(nn.Module): #상속

  def __init__(self , vocab_built , emb_dim , dim_channel , kernel_wins , num_class): #초기화
                     # train 데이터의 단어장을 인자로 받음 , emb_dim : 임베딩 벡터의 크기를 인자로 
                     #다양한 인자를 받음 
    super(TextCNN , self).__init__() #module 에 있는 메소드를 상속받아서

    self.embed = nn.Embedding(len(vocab_built) , emb_dim)
    self.embed.weight.data.copy_(vocab_built.vectors)
    self.convs = nn.ModuleList([nn.Conv2d(1 , dim_channel , (w , emb_dim)) for w in kernel_wins]) #conv2d에 결과를 전달해 filter 생성
    self.relu = nn.ReLU()
    self.dropout = nn.Dropout(0.4)#오버피팅 방지
    self.fc = nn.Linear(len(kernel_wins)* dim_channel , num_class)
      #fully connected layer

  def forward(self , x): #forward propagation 을 정의 (설계한 모델에서 output 까지의 결과 과정 기술)
    emb_x = self.embed(x)
    emb_x = emb_x.unsqueeze(1)  #차원 추가

    con_x = [self.relu(conv(emb_x)) for conv in self.convs]

    pool_x = [F.max_pool1d(x.squeeze(-1) , x.size()[2]) for x in con_x] #max_pooling 

    fc_x = torch.cat(pool_x , dim = 1)
    fc_x = fc_x.squeeze(-1)
    fc_x = self.dropout(fc_x)

    logit = self.fc(fc_x)

    return logit

# %%
def train(model , device , train_itr , optimizer):
  model.train()
  corrects , train_loss = 0.0 , 0

  for batch in train_itr:

    text , target = batch.text , batch.label
    text= torch.transpose(text , 0 , 1)
    target.data.sub_(1)
    text  , target = text.to(device) , target.to(device)

    optimizer.zero_grad()
    logit = model(text)

    loss = F.cross_entropy(logit , target)
    loss.backward()
    optimizer.step()

    train_loss+= loss.item()
    result = torch.max(logit , 1)[1]
    corrects += (result.view(target.size()).data == target.data).sum()

  train_loss /= len(train_itr.dataset)
  accuracy = 100.0 * corrects/ len(train_itr.dataset)

  return train_loss , accuracy

# %% [markdown]
# 모델 평가 함수 정의

# %%
def evaluate(model , device , itr):
  model.eval()
  corrects , test_loss = 0.0 , 0

  for batch in itr:
    text = batch.text
    target = batch.label

    text = torch.transpose(text , 0 , 1)
    target.data.sub_(1)
    text , target = text.to(device) , target.to(device)
    logit = model(text)
    loss = F.cross_entropy(logit , target)

    test_loss += loss.item()
    result = torch.max(logit , 1)[1]
    corrects += (result.view(target.size()).data == target.data).sum()

    test_loss /= len(itr.dataset)
    accuracy = 100.0 * corrects / len(itr.dataset)
    return test_loss , accuracy

# %%
model = TextCNN(vocab , 100 ,10 , [3,4,5] , 2).to('cuda')

# %%
print(model)
# Out:
# TextCNN(
#   (embed): Embedding(3882, 100)
#   (convs): ModuleList(
#     (0): Conv2d(1, 10, kernel_size=(3, 100), stride=(1, 1))
#     (1): Conv2d(1, 10, kernel_size=(4, 100), stride=(1, 1))
#     (2): Conv2d(1, 10, kernel_size=(5, 100), stride=(1, 1))
#   )
#   (relu): ReLU()
#   (dropout): Dropout(p=0.4, inplace=False)
#   (fc): Linear(in_features=30, out_features=2, bias=True)
# )

# %%
device = "cuda"

optimizer = optim.Adam(model.parameters(), lr=0.001)

best_test_acc = -1

for epoch in range(1, 3+1):
 
    tr_loss, tr_acc = train(model, device, train_iter, optimizer) 
    print('Train Epoch: {} \t Loss: {} \t Accuracy: {}%'.format(epoch, tr_loss, tr_acc))
    
    val_loss, val_acc = evaluate(model, device, validation_iter)
    print('Valid Epoch: {} \t Loss: {} \t Accuracy: {}%'.format(epoch, val_loss, val_acc))
        
    if val_acc > best_test_acc:
        best_test_acc = val_acc
        
        print("model saves at {} accuracy".format(best_test_acc))
        torch.save(model.state_dict(), "TextCNN_Best_Validation")
    
    print('-----------------------------------------------------------------------------')
# Out:
# Train Epoch: 1 	 Loss: 0.09209813412867095 	 Accuracy: 42.105262756347656%
# Valid Epoch: 1 	 Loss: 0.0786306725607978 	 Accuracy: 11.111111640930176%
# model saves at 11.111111640930176 accuracy
# -----------------------------------------------------------------------------
# Train Epoch: 2 	 Loss: 0.09136115720397547 	 Accuracy: 44.73684310913086%
# Valid Epoch: 2 	 Loss: 0.07752143012152778 	 Accuracy: 11.111111640930176%
# -----------------------------------------------------------------------------
# Train Epoch: 3 	 Loss: 0.09039217233657837 	 Accuracy: 57.894737243652344%
# Valid Epoch: 3 	 Loss: 0.07695602708392674 	 Accuracy: 55.55555725097656%
# model saves at 55.55555725097656 accuracy
# -----------------------------------------------------------------------------
